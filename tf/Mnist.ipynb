# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
(ds_train, ds_test), ds_info = tfds.load(
    'mnist',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True
)

# %%
def normalize_img(image, label):
  return tf.cast(image, tf.float32) / 255., label

ds_train = ds_train.map(
    normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.shuffle(ds_info.splits['train'].num_examples)
ds_train = ds_train.batch(512)
ds_train = ds_train.cache()
ds_train = ds_train.prefetch(tf.data.AUTOTUNE)

ds_test = ds_test.map(
    normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_test = ds_test.batch(512)
ds_test = ds_test.cache()
ds_test = ds_test.prefetch(tf.data.AUTOTUNE)

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='sigmoid'))    

model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

filename = 'MNIST.h5'

checkpoint = ModelCheckpoint(filename,             
                             monitor='val_loss',   
                             verbose=1,            
                             save_best_only=True,  
                             mode='auto'           
                            )

earlystopping = EarlyStopping(monitor='val_loss',  
                              patience=10,         
                             )

# %%
history =  model.fit(
    ds_train,
    epochs=60,
    validation_data=ds_test,
    callbacks=[checkpoint, earlystopping],
)
# Out:
# Epoch 1/60
# 118/118 [==============================] - 7s 16ms/step - loss: 0.5698 - sparse_categorical_accuracy: 0.8367 - val_loss: 0.1503 - val_sparse_categorical_accuracy: 0.9555
#
# Epoch 00001: val_loss improved from inf to 0.15027, saving model to MNIST.h5
# Epoch 2/60
# 118/118 [==============================] - 1s 9ms/step - loss: 0.1234 - sparse_categorical_accuracy: 0.9621 - val_loss: 0.0914 - val_sparse_categorical_accuracy: 0.9712
#
# Epoch 00002: val_loss improved from 0.15027 to 0.09139, saving model to MNIST.h5
# Epoch 3/60
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0814 - sparse_categorical_accuracy: 0.9746 - val_loss: 0.0632 - val_sparse_categorical_accuracy: 0.9809
#
# Epoch 00003: val_loss improved from 0.09139 to 0.06323, saving model to MNIST.h5
# Epoch 4/60
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0641 - sparse_categorical_accuracy: 0.9804 - val_loss: 0.0537 - val_sparse_categorical_accuracy: 0.9839
#
# Epoch 00004: val_loss improved from 0.06323 to 0.05368, saving model to MNIST.h5
# Epoch 5/60
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0529 - sparse_categorical_accuracy: 0.9839 - val_loss: 0.0468 - val_sparse_categorical_accuracy: 0.9862
#
# Epoch 00005: val_loss improved from 0.05368 to 0.04678, saving model to MNIST.h5
# Epoch 6/60
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0456 - sparse_categorical_accuracy: 0.9862 - val_loss: 0.0449 - val_sparse_categorical_accuracy: 0.9860
#
# Epoch 00006: val_loss improved from 0.04678 to 0.04488, saving model to MNIST.h5
# Epoch 7/60
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0393 - sparse_categorical_accuracy: 0.9878 - val_loss: 0.0435 - val_sparse_categorical_accuracy: 0.9859
#
# Epoch 00007: val_loss improved from 0.04488 to 0.04345, saving model to MNIST.h5
# Epoch 8/60
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0343 - sparse_categorical_accuracy: 0.9895 - val_loss: 0.0411 - val_sparse_categorical_accuracy: 0.9873
#
# Epoch 00008: val_loss improved from 0.04345 to 0.04113, saving model to MNIST.h5
# Epoch 9/60
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0306 - sparse_categorical_accuracy: 0.9908 - val_loss: 0.0399 - val_sparse_categorical_accuracy: 0.9874
#
# Epoch 00009: val_loss improved from 0.04113 to 0.03986, saving model to MNIST.h5
# Epoch 10/60
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0277 - sparse_categorical_accuracy: 0.9919 - val_loss: 0.0377 - val_sparse_categorical_accuracy: 0.9885
#
# Epoch 00010: val_loss improved from 0.03986 to 0.03765, saving model to MNIST.h5
# Epoch 11/60
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0249 - sparse_categorical_accuracy: 0.9927 - val_loss: 0.0365 - val_sparse_categorical_accuracy: 0.9895
#
# Epoch 00011: val_loss improved from 0.03765 to 0.03650, saving model to MNIST.h5
# Epoch 12/60
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0223 - sparse_categorical_accuracy: 0.9935 - val_loss: 0.0369 - val_sparse_categorical_accuracy: 0.9903
#
# Epoch 00012: val_loss did not improve from 0.03650
# Epoch 13/60
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0203 - sparse_categorical_accuracy: 0.9940 - val_loss: 0.0356 - val_sparse_categorical_accuracy: 0.9902
#
# Epoch 00013: val_loss improved from 0.03650 to 0.03565, saving model to MNIST.h5
# Epoch 14/60
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0187 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.0341 - val_sparse_categorical_accuracy: 0.9907
#
# Epoch 00014: val_loss improved from 0.03565 to 0.03414, saving model to MNIST.h5
# Epoch 15/60
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0180 - sparse_categorical_accuracy: 0.9944 - val_loss: 0.0341 - val_sparse_categorical_accuracy: 0.9909
#
# Epoch 00015: val_loss improved from 0.03414 to 0.03412, saving model to MNIST.h5
# Epoch 16/60
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0179 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.0373 - val_sparse_categorical_accuracy: 0.9885
#
# Epoch 00016: val_loss did not improve from 0.03412
# Epoch 17/60
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0164 - sparse_categorical_accuracy: 0.9948 - val_loss: 0.0374 - val_sparse_categorical_accuracy: 0.9885
#
# Epoch 00017: val_loss did not improve from 0.03412
# Epoch 18/60
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0167 - sparse_categorical_accuracy: 0.9945 - val_loss: 0.0372 - val_sparse_categorical_accuracy: 0.9893
#
# Epoch 00018: val_loss did not improve from 0.03412
# Epoch 19/60
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0154 - sparse_categorical_accuracy: 0.9949 - val_loss: 0.0348 - val_sparse_categorical_accuracy: 0.9894
#
# Epoch 00019: val_loss did not improve from 0.03412
# Epoch 20/60
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0141 - sparse_categorical_accuracy: 0.9954 - val_loss: 0.0370 - val_sparse_categorical_accuracy: 0.9894
#
# Epoch 00020: val_loss did not improve from 0.03412
# Epoch 21/60
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0124 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.0413 - val_sparse_categorical_accuracy: 0.9879
#
# Epoch 00021: val_loss did not improve from 0.03412
# Epoch 22/60
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0111 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0347 - val_sparse_categorical_accuracy: 0.9903
#
# Epoch 00022: val_loss did not improve from 0.03412
# Epoch 23/60
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0095 - sparse_categorical_accuracy: 0.9971 - val_loss: 0.0357 - val_sparse_categorical_accuracy: 0.9914
#
# Epoch 00023: val_loss did not improve from 0.03412
# Epoch 24/60
# 118/118 [==============================] - 1s 9ms/step - loss: 0.0089 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.0358 - val_sparse_categorical_accuracy: 0.9911
#
# Epoch 00024: val_loss did not improve from 0.03412
# Epoch 25/60
# 118/118 [==============================] - 1s 8ms/step - loss: 0.0086 - sparse_categorical_accuracy: 0.9973 - val_loss: 0.0367 - val_sparse_categorical_accuracy: 0.9907
#
# Epoch 00025: val_loss did not improve from 0.03412
